# %%
# The %... is an iPython thing, and is not part of the Python language.
# In this case we're just telling the plotting library to draw things on
# the notebook, instead of on a separate window.
# %matplotlib inline 
#this line above prepares IPython notebook for working with matplotlib

# See all the "as ..." contructs? They're just aliasing the package names.
# That way we can call methods like plt.plot() instead of matplotlib.pyplot.plot().

import numpy as np # imports a fast numerical programming library
import scipy as sp #imports stats functions, amongst other things
import matplotlib as mpl # this actually imports matplotlib
import matplotlib.cm as cm #allows us easy access to colormaps
import matplotlib.pyplot as plt #sets up plotting under plt
import pandas as pd #lets us handle data as dataframes
#sets up pandas table display
pd.set_option('display.width', 500)
pd.set_option('display.max_columns', 100)
pd.set_option('display.notebook_repr_html', True)
import seaborn as sns #sets up styles and gives us more plotting options

# %%
# GLD (gold prices)
u_cols = ['Date','USD (AM)','Close','GBP (AM)','GBP (PM)','EURO (AM)','EURO (PM)']
gold = pd.read_csv('../data/GLD.csv', names=u_cols, header=0)
gold.head()
# Out:
#          Date  USD (AM)    Close  GBP (AM)  GBP (PM)  EURO (AM)  EURO (PM)
# 0  2017-02-27   1256.25      NaN   1011.16       NaN    1187.41        NaN
# 1  2017-02-24   1255.35  1253.65   1000.89   1001.79    1185.18    1185.58
# 2  2017-02-23   1237.35  1247.90    992.97    997.70    1173.13    1179.39
# 3  2017-02-22   1237.50  1236.65    994.21    992.41    1178.22    1176.67
# 4  2017-02-21   1228.70  1233.20    988.86    991.62    1166.16    1170.31

# %%
gold['Date'] = gold.Date.astype('datetime64[ns]')
print gold.dtypes
print gold.shape
# Out:
# Date         datetime64[ns]
# USD (AM)            float64
# Close               float64
# GBP (AM)            float64
# GBP (PM)            float64
# EURO (AM)           float64
# EURO (PM)           float64
# dtype: object
# (12425, 7)

# %%
# Remove columns we don't care about
gold = gold.drop(['EURO (PM)', 'EURO (AM)', 'GBP (PM)', 'GBP (AM)', 'USD (AM)'], 1)

# %%
gold = gold.dropna()

# %%
gold.shape
# Out:
# (12289, 2)

# %%
plt.figure(figsize=[25,10])
plt.plot(gold.Date, gold.Close, 'o-', label='GLD', markevery=1)
plt.legend(loc = 'lower right')
plt.xlabel("Date")
plt.ylabel("Price")

# %%
# SPY index 
u_cols = ['Date','Open','High','Low','Close','Volume', 'Adjusted Close']
s_and_p =pd.read_csv('../data/SPY.csv', names=u_cols, header=0)
s_and_p.head()
# Out:
#          Date         Open         High          Low        Close        Volume  Adjusted Close
# 0  2017-02-24  2355.729980  2367.340088  2352.870117  2367.340088  3.831570e+09     2367.340088
# 1  2017-02-23  2367.500000  2368.260010  2355.090088  2363.810059  4.015260e+09     2363.810059
# 2  2017-02-22  2361.110107  2365.129883  2358.340088  2362.820068  3.468670e+09     2362.820068
# 3  2017-02-21  2354.909912  2366.709961  2354.909912  2365.379883  3.579780e+09     2365.379883
# 4  2017-02-17  2343.010010  2351.159912  2339.580078  2351.159912  3.513060e+09     2351.159912

# %%
s_and_p['Date'] = s_and_p.Date.astype('datetime64[ns]')
print s_and_p.dtypes
print s_and_p.shape
# Out:
# Date              datetime64[ns]
# Open                     float64
# High                     float64
# Low                      float64
# Close                    float64
# Volume                   float64
# Adjusted Close           float64
# dtype: object
# (16896, 7)

# %%
# Remove columns we don't care about
s_and_p = s_and_p.drop(['Open', 'High', 'Low', 'Volume', 'Adjusted Close'], 1)

# %%
s_and_p.dropna()
s_and_p.shape
# Out:
# (16896, 2)

# %%
s_and_p.head()
# Out:
#         Date        Close
# 0 2017-02-24  2367.340088
# 1 2017-02-23  2363.810059
# 2 2017-02-22  2362.820068
# 3 2017-02-21  2365.379883
# 4 2017-02-17  2351.159912

# %%
plt.figure(figsize=[25,10])
plt.plot(s_and_p.Date, s_and_p.Close, 'o-', label='SPY', markevery=1)
plt.legend(loc = 'lower right')
plt.xlabel("Date")
plt.ylabel("Price")

# %%
# Gold and S&P 500
plt.figure(figsize=[25,10])
plt.plot(s_and_p.Date, s_and_p.Close, 'o-', label='SPY', markevery=1)
plt.plot(gold.Date, gold.Close, 'o-', label='GLD', markevery=1)
plt.legend(loc = 'lower right')
plt.xlabel("Date")
plt.ylabel("Price")

# %%
# Gold and S&P 500(2005-01-01, 2012-01-01)
plt.figure(figsize=[25,10])
plt.plot(s_and_p.Date, s_and_p.Close, 'o-', label='SPY', markevery=1)
plt.plot(gold.Date, gold.Close, 'o-', label='GLD', markevery=1)
plt.legend(loc = 'lower right')
plt.xlabel("Date")
plt.ylabel("Price")
plt.xlim(['2005-01-01','2012-01-01'])
# Out:
# (731947.0, 734503.0)

# %%
# Gold and S&P 500 old school(1970-01-01, 1980-01-01)
plt.figure(figsize=[25,10])
plt.plot(s_and_p.Date, s_and_p.Close, 'o-', label='SPY', markevery=1)
plt.plot(gold.Date, gold.Close, 'o-', label='GLD', markevery=1)
plt.legend(loc = 'lower right')
plt.xlabel("Date")
plt.ylabel("Price")
plt.xlim(['1970-01-01','1980-01-01'])
plt.ylim([0,500])
# Out:
# (0, 500)

# %%
s_and_p_sorted = s_and_p.sort('Date')
# Out:
# /Users/parthshah/.virtualenvs/machine-learning/lib/python2.7/site-packages/ipykernel/__main__.py:1: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   if __name__ == '__main__':

# %%
s_and_p_sorted.head()
# Out:
#             Date  Close
# 16895 1950-01-03  16.66
# 16894 1950-01-04  16.85
# 16893 1950-01-05  16.93
# 16892 1950-01-06  16.98
# 16891 1950-01-09  17.08

# %%
returns_over_30 = s_and_p_sorted.Close.pct_change(periods=30)

# %%
s_and_p_sorted['30_day_return'] = returns_over_30

# %%
s_and_p_sorted = s_and_p_sorted.dropna()

# %%
gold_sorted = gold.sort('Date')
gold_sorted.head()
gold_sorted.Close.head()
# Out:
# /Users/parthshah/.virtualenvs/machine-learning/lib/python2.7/site-packages/ipykernel/__main__.py:1: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   if __name__ == '__main__':
# 12371    37.70
# 12370    37.30
# 12369    37.60
# 12368    36.95
# 12367    37.00
# Name: Close, dtype: float64

# %%
returns_over_30 = gold_sorted.Close.pct_change(30)
gold_sorted['30_day_return'] = returns_over_30
gold_sorted = gold_sorted.dropna()

plt.figure(figsize=[25,10])
plt.plot(s_and_p_sorted.Date, s_and_p_sorted['30_day_return'], 'o-', label='SPY', markevery=1)
plt.plot(gold_sorted.Date, gold_sorted['30_day_return'], 'o-', label='GLD', markevery=1)
plt.legend(loc = 'lower right')
plt.xlabel("Date")
plt.ylabel("Percent Change")
plt.xlim(['1970-01-01','1980-01-01'])
# Out:
# (719163.0, 722815.0)

# %%
s_and_p_sorted.head()
# Out:
#             Date      Close  30_day_return
# 16865 1950-02-15  17.059999       0.024010
# 16864 1950-02-16  16.990000       0.008309
# 16863 1950-02-17  17.150000       0.012995
# 16862 1950-02-20  17.200001       0.012956
# 16861 1950-02-21  17.170000       0.005269
